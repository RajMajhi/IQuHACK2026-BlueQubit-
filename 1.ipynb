# %%
# !pip install qiskit
# !pip install matplotlib
# !pip install pylatexenc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 54.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=7b53ddee1bb850c4ab893b5e0704b72c63290f3545307da5d04f477d3ddb558b
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# ...

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
import numpy as np

# %%
qc = QuantumCircuit.from_qasm_file("P1_little_peak.qasm")

qc.draw("mpl")

# %%
state = Statevector.from_instruction(qc)

probabilities = state.probabilities_dict()

probabilities
# Out:
# {np.str_('1001'): np.float64(1.0)}

# %%
peak_bitstring = max(probabilities, key=probabilities.get)
peak_probability = probabilities[peak_bitstring]

print("Peak bitstring:", peak_bitstring)
print("Probability:", peak_probability)
# Out:
# Peak bitstring: 1001
# Probability: 1.0

# %%
plot_histogram(probabilities)
plt.show()

# %%
labels = list(probabilities.keys())
values = list(probabilities.values())

plt.figure(figsize=(8,4))
plt.bar(labels, values)
plt.xlabel("Bitstring")
plt.ylabel("Probability")
plt.title("Probability Distribution")
plt.xticks(rotation=90)
plt.show()

# %%
print(state)
# Out:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2))
